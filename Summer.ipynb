# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("summer.csv")
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
df['City'].unique()
# Out:
# array(['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp',
#        'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki',
#        'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich',
#        'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney',
#        'Beijing'], dtype=object)

# %%
len(df['City'].unique())
# Out:
# 22

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
data = []

a = df[df['Medal'] == 'Gold']

data.append(a)
a
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
p_data = []

for Sport in a['Sport'].unique():
    p_data.append([Sport , len(a[a['Sport'] == Sport])])
    
p_data = pd.DataFrame(p_data,columns = ['Sport','Medal'])
p_data = p_data.sort_values(by='Medal', ascending = False).head()
p_data
# Out:
#          Sport  Medal
# 0     Aquatics   1421
# 1    Athletics   1215
# 17      Rowing    890
# 4   Gymnastics    820
# 3      Fencing    552

# %%
p_data.plot( x = 'Sport', y = 'Medal', kind = 'bar', color = 'orange', figsize = (10,5))
plt.title('BarPlot')
# Out:
# Text(0.5, 1.0, 'BarPlot')

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
data = []

for Sport in df['Sport'].unique():
    data.append([Sport , len(df[df['Sport'] == Sport])])

# %%
data = pd.DataFrame(data,columns = ['Sport','Medal'])

data = data.sort_values(by='Medal', ascending = False).head()
data
# Out:
#          Sport  Medal
# 0     Aquatics   4170
# 1    Athletics   3638
# 17      Rowing   2667
# 4   Gymnastics   2307
# 3      Fencing   1613

# %%
data.plot( x = 'Sport', y = 'Medal', kind = 'bar', figsize = (10,5))
plt.title('BarPlot')
# Out:
# Text(0.5, 1.0, 'BarPlot')

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
data = []

for Athlete in df['Athlete'].unique():
    data.append([Athlete , len(df[df['Athlete'] == Athlete])])
    
data = pd.DataFrame(data,columns = ['Athlete','Medal'])

data = data.sort_values(by='Medal', ascending = False).head()

# %%
data
# Out:
#                     Athlete  Medal
# 18640       PHELPS, Michael     22
# 7197       LATYNINA, Larisa     18
# 9948     ANDRIANOV, Nikolay     15
# 6591           ONO, Takashi     13
# 5103   MANGIAROTTI, Edoardo     13

# %%
data.plot( x = 'Athlete', y = 'Medal', kind = 'bar', figsize = (10,5))
plt.title('BarPlot')
# Out:
# Text(0.5, 1.0, 'BarPlot')

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
data = []

a = df[df['Medal'] == 'Gold']

data.append(a)
a
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
p_data = []

for Athlete in a['Athlete'].unique():
    p_data.append([Athlete , len(a[a['Athlete'] == Athlete])])
    
p_data = pd.DataFrame(p_data,columns = ['Athlete','Medal'])
p_data = p_data.sort_values(by='Medal', ascending = False).head()
p_data
# Out:
#                Athlete  Medal
# 6851   PHELPS, Michael     18
# 3320       SPITZ, Mark      9
# 2714  LATYNINA, Larisa      9
# 4630       LEWIS, Carl      9
# 907       NURMI, Paavo      9

# %%
p_data.plot( x = 'Athlete', y = 'Medal', kind = 'bar', color = 'orange', figsize = (10,5))
plt.title('BarPlot')
# Out:
# Text(0.5, 1.0, 'BarPlot')

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
data = []

a = df[df['Medal'] == 'Gold']

data.append(a)

# %%
data1 = []

b = a[a['Country'] == 'IND']

data1.append(b)
b.sort_values(by='Year', ascending = True).head(1)
# Out:
#       Year       City   Sport Discipline               Athlete Country Gender  \
# 5512  1928  Amsterdam  Hockey     Hockey  ALLEN, Richard James     IND    Men
#
#        Event Medal
# 5512  Hockey  Gold

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
data = []

for Event in df['Event'].unique():
    data.append([Event , len(df[df['Event'] == Event])])
    
data = pd.DataFrame(data,columns = ['Event','Athlete'])
data = data.sort_values(by='Athlete', ascending = False).head()

# %%
data
# Out:
#                 Event  Athlete
# 80           Football     1497
# 176            Hockey     1422
# 138  Team Competition     1147
# 327        Basketball     1012
# 337          Handball      973

# %%
data.plot( x = 'Event', y = 'Athlete', kind = 'bar', figsize = (10,5))
plt.title('BarPlot')
# Out:
# Text(0.5, 1.0, 'BarPlot')

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
data = []

a = df[df['Medal'] == 'Gold']

data.append(a)

# %%
data1 = []

b = a[a['Gender'] == 'Women']

data1.append(b)

# %%
b
# Out:
#        Year      City          Sport           Discipline  \
# 417    1900     Paris           Golf                 Golf
# 641    1900     Paris         Tennis               Tennis
# 649    1900     Paris         Tennis               Tennis
# 710    1904  St Louis        Archery              Archery
# 713    1904  St Louis        Archery              Archery
# ...     ...       ...            ...                  ...
# 31081  2012    London  Weightlifting        Weightlifting
# 31097  2012    London      Wrestling  Wrestling Freestyle
# 31105  2012    London      Wrestling  Wrestling Freestyle
# 31113  2012    London      Wrestling  Wrestling Freestyle
# 31121  2012    London      Wrestling  Wrestling Freestyle
#
#                      Athlete Country Gender  \
# 417    ABBOTT, Margaret Ives     USA  Women
# 641        COOPER, Charlotte     GBR  Women
# 649        COOPER, Charlotte     GBR  Women
# 710    HOWELL, Matilda Scott     USA  Women
# ...

# %%
p_data = []

for Sport in b['Sport'].unique():
    p_data.append([Sport , len(b[b['Sport'] == Sport])])
    
p_data = pd.DataFrame(p_data,columns = ['Sport','Medal'])
p_data = p_data.sort_values(by='Medal', ascending = False).head()
p_data
# Out:
#          Sport  Medal
# 4     Aquatics    589
# 7    Athletics    389
# 8   Gymnastics    268
# 14      Rowing    217
# 11  Volleyball    166

# %%
p_data.plot( x = 'Sport', y = 'Medal', kind = 'bar', color = 'orange', figsize = (10,5))
plt.title('BarPlot')
# Out:
# Text(0.5, 1.0, 'BarPlot')
